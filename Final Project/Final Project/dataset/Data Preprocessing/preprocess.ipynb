# %%
import json

input_path = "dataset/BeaverTails/round0/330k/train.jsonl"       # your current file
output_path = "ft_data.jsonl"       # file to use for fine-tuning

with open(input_path, "r", encoding="utf-8") as fin, \
     open(output_path, "w", encoding="utf-8") as fout:
    for line in fin:
        if not line.strip():
            continue
        ex = json.loads(line)
        
        # filter on safety
        if not ex.get("is_safe", False):
            continue

        # build fine-tune record
        record = {
            "input": ex["prompt"],
            "output": ex["response"]
        }
        fout.write(json.dumps(record, ensure_ascii=False) + "\n")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[5], line 6
#       3 input_path = "dataset/BeaverTails/round0/330k/train.jsonl"       # your current file
#       4 output_path = "ft_data.jsonl"       # file to use for fine-tuning
# ----> 6 with open(input_path, "r", encoding="utf-8") as fin, \
#       7      open(output_path, "w", encoding="utf-8") as fout:
#       8     for line in fin:
#       9         if not line.strip():
#
# File ~\AppData\Roaming\Python\Python312\site-packages\IPython\core\interactiveshell.py:310, in _modified_open(file, *args, **kwargs)
#     303 if file in {0, 1, 2}:
#     304     raise ValueError(
#     305         f"IPython won't let you open fd={file} by default "
#     306         "as it is likely to crash IPython. If you know what you are doing, "
#     307         "you can use builtins' open."
#     308     )
# ...
